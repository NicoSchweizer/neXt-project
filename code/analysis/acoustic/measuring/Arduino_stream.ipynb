# %%
import sounddevice as sd

sd.query_devices()
# Out:
#   0 PL2480H, Core Audio (0 in, 2 out)
# > 1 AirPods Pro von Nico, Core Audio (1 in, 0 out)
# < 2 AirPods Pro von Nico, Core Audio (0 in, 2 out)
#   3 MacBook Air-Mikrofon, Core Audio (1 in, 0 out)
#   4 MacBook Air-Lautsprecher, Core Audio (0 in, 2 out)
#   5 Mikrofon von „iPhone von Nico“, Core Audio (1 in, 0 out)
